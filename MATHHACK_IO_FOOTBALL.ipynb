# %%
import pandas as pd

df =pd.read_csv("LHS_WE_2_Soccer_Fever_train.csv")

df.head()
# Out:
#    season      date  league_id                league                Team 1  \
# 0    2019  01/03/19       1979  Chinese Super League       Shandong Luneng
# 1    2019  01/03/19       1979  Chinese Super League    Shanghai Greenland
# 2    2019  01/03/19       1979  Chinese Super League  Guangzhou Evergrande
# 3    2019  01/03/19       1979  Chinese Super League            Wuhan Zall
# 4    2019  01/03/19       1979  Chinese Super League       Chongqing Lifan
#
#                Team2   SPI1   SPI2  proj_score1  proj_score2  ...  \
# 0      Guizhou Renhe  48.22  37.83         1.75         0.84  ...
# 1      Shanghai SIPG  39.81  60.08         1.22         1.89  ...
# 2  Tianjin Quanujian  65.59  39.99         2.58         0.62  ...
# 3      Beijing Guoan  32.25  54.82         1.10         1.79  ...
# 4       Guangzhou RF  38.24  40.45         1.57         1.24  ...
#
#    importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  \
# ...

# %%
df.describe()
# Out:
#             season    league_id         SPI1         SPI2  ...        nsxg2   adj_score1   adj_score2      Outcome
# count  7443.000000  7443.000000  7443.000000  7443.000000  ...  1715.000000  1715.000000  1715.000000  7443.000000
# mean   2020.846702  2264.435980    40.447416    40.486339  ...     1.108700     1.510140     1.230000     0.681177
# std       0.440811  1033.343797    18.367631    18.356843  ...     0.561853     1.226182     1.106616     0.466052
# min    2019.000000  1818.000000     4.710000     4.720000  ...     0.000000     0.000000     0.000000     0.000000
# 25%    2021.000000  1859.000000    28.010000    27.990000  ...     0.710000     1.050000     0.000000     0.000000
# 50%    2021.000000  1948.000000    38.260000    38.290000  ...     1.020000     1.050000     1.050000     1.000000
# 75%    2021.000000  2160.000000    52.160000    52.380000  ...     1.390000     2.100000     2.100000     1.000000
# ...

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'Team 1', 'Team2', 'SPI1',
#        'SPI2', 'proj_score1', 'proj_score2', 'importance1', 'importance2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7443 entries, 0 to 7442
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       7443 non-null   int64
#  1   date         7443 non-null   object
#  2   league_id    7443 non-null   int64
#  3   league       7443 non-null   object
#  4   Team 1       7443 non-null   object
#  5   Team2        7443 non-null   object
#  6   SPI1         7443 non-null   float64
#  7   SPI2         7443 non-null   float64
#  8   proj_score1  7443 non-null   float64
#  9   proj_score2  7443 non-null   float64
#  10  importance1  2527 non-null   float64
#  11  importance2  2527 non-null   float64
#  12  score1       2643 non-null   float64
#  13  score2       2643 non-null   float64
#  14  xg1          1715 non-null   float64
#  15  xg2          1715 non-null   float64
#  16  nsxg1        1715 non-null   float64
#  17  nsxg2        1715 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# season         0
# date           0
# league_id      0
# league         0
# Team 1         0
# Team2          0
# SPI1           0
# SPI2           0
# proj_score1    0
# proj_score2    0
# importance1    0
# importance2    0
# score1         0
# score2         0
# xg1            0
# xg2            0
# nsxg1          0
# nsxg2          0
# adj_score1     0
# adj_score2     0
# Outcome        0
# dtype: int64

# %%
df['importance1'].fillna(df['importance1'].mode()[0], inplace=True)
df['importance2'].fillna(df['importance2'].mode()[0], inplace=True)
df['score1'].fillna(df['score1'].mode()[0], inplace=True)
df['score2'].fillna(df['score2'].mode()[0], inplace=True)
df['xg1'].fillna(df['xg1'].mode()[0], inplace=True)
df['xg2'].fillna(df['xg2'].mode()[0], inplace=True)
df['nsxg1'].fillna(df['nsxg1'].mode()[0], inplace=True)
df['nsxg2'].fillna(df['nsxg2'].mode()[0], inplace=True)
df['adj_score1'].fillna(df['adj_score1'].mode()[0], inplace=True)
df['adj_score2'].fillna(df['adj_score2'].mode()[0], inplace=True)

# %%
df.boxplot(column=['importance1'])
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# season         0
# date           0
# league_id      0
# league         0
# Team 1         0
# Team2          0
# SPI1           0
# SPI2           0
# proj_score1    0
# proj_score2    0
# importance1    0
# importance2    0
# score1         0
# score2         0
# xg1            0
# xg2            0
# nsxg1          0
# nsxg2          0
# adj_score1     0
# adj_score2     0
# Outcome        0
# dtype: int64

# %%
df1['season'].value_counts()
# Out:
# 2021    6542
# 2020     661
# 2019     240
# Name: season, dtype: int64

# %%
df1['league_id'].value_counts()
# Out:
# 2160    496
# 1951    459
# 2105    380
# 1947    380
# 5641    325
# 2413    264
# 2412    264
# 2414    252
# 1979    240
# 1859    240
# 1874    240
# 1871    220
# 1820    204
# 1844    180
# 1843    180
# 1975    171
# 1869    170
# 1856    170
# 1854    170
# 1832    162
# 1948    161
# 1882    160
# 2411    160
# 1846    153
# 1952    153
# 1849    144
# 1866    144
# 1845    135
# 1864    126
# 1818    125
# 4582    120
# 1983    119
# 1827    108
# 2417    108
# 1837    102
# 1884     98
# 1879     85
# 7921     54
# 9541     21
# Name: league_id, dtype: int64

# %%
df1['league'].value_counts()
# Out:
# United Soccer League                        496
# Major League Soccer                         459
# Brasileiro Série A                          380
# Japanese J League                           380
# APD                                         325
# English League One                          264
# English League Championship                 264
# English League Two                          252
# Swedish Allsvenskan                         240
# Chinese Super League                        240
# Norwegian Tippeligaen                       240
# Spanish Segunda Division                    220
# UEFA Europa League                          204
# French Ligue 2                              180
# French Ligue 1                              180
# Mexican Primera Division Torneo Clausura    171
# Italy Serie A                               170
# Italy Serie B                               170
# Spanish Primera Division                    170
# BJL                                         162
# ...

# %%
cont_cols=['SPI1','SPI2', 'proj_score1', 'proj_score2', 'importance1', 'importance2',
       'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
       'adj_score2']

cat_cols =['season', 'date', 'league_id', 'league', 'Team 1', 'Team2']

y=df['Outcome']

# %%
df_corr=df[cont_cols]

X=df_corr

# %%
df_cat=df[cat_cols]

X=df_cat

# %%
import matplotlib.pyplot as plt
import seaborn as sn

dfCorr = df.corr()
filteredDf = dfCorr[((dfCorr >= .5) | (dfCorr <= -.5)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,10))
sn.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
from sklearn.feature_selection import chi2

chi_scores = chi2(X,y)

p_values = pd.Series(chi_scores[1],index = X.columns)
p_values.sort_values(ascending = False , inplace = True)

# %%
p_values.plot.bar()
# Out:
# <AxesSubplot:>

# %%
cont_cols=[ 'SPI1' , 'SPI2','proj_score1','proj_score2','importance1','importance2','score1','score2','xg1','adj_score1']

cat_cols =['season', 'date', 'league_id', 'league', 'Team 1', 'Team2']

y=df['Outcome']

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_regression

X_clf_new=SelectKBest(score_func=chi2,k=10).fit_transform(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13956/2241125130.py in <module>
#       1 from sklearn.feature_selection import SelectKBest, chi2, f_regression
#       2
# ----> 3 X_clf_new=SelectKBest(score_func=chi2,k=10).fit_transform(X,y)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
# --> 693             return self.fit(X, y, **fit_params).transform(X)
#     694
#     695
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     342         self : object
#     343         """
# --> 344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
# ...

# %%
print(X_clf_new[:10])
# Out:
# [[48.22 37.83  1.75  0.84 45.9  22.1   1.    0.    1.39  1.05]
#  [39.81 60.08  1.22  1.89 25.6  63.4   0.    4.    0.57  0.  ]
#  [65.59 39.99  2.58  0.62 77.1  28.8   3.    0.    0.49  3.15]
#  [32.25 54.82  1.1   1.79 35.8  58.9   0.    1.    1.12  0.  ]
#  [38.24 40.45  1.57  1.24 26.2  21.3   2.    2.    2.77  2.1 ]
#  [31.99 38.75  1.41  1.25 40.5  24.6   3.    1.    1.33  2.61]
#  [35.18 45.83  1.22  1.29 33.1  41.    1.    1.    0.84  1.05]
#  [51.59 36.92  1.92  0.78 51.4  25.9   3.    2.    3.28  2.61]
#  [65.34 36.68  2.74  0.58 78.7  24.3   1.    0.    1.74  1.05]
#  [37.51 54.42  1.19  1.67 28.   64.3   0.    4.    0.54  0.  ]]

# %%
X
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     48.22  37.83         1.75         0.84         45.9         22.1
# 1     39.81  60.08         1.22         1.89         25.6         63.4
# 2     65.59  39.99         2.58         0.62         77.1         28.8
# 3     32.25  54.82         1.10         1.79         35.8         58.9
# 4     38.24  40.45         1.57         1.24         26.2         21.3
# ...     ...    ...          ...          ...          ...          ...
# 7438  34.05  33.76         1.39         1.19        100.0        100.0
# 7439  36.73  36.11         1.67         1.44        100.0        100.0
# 7440  12.97  23.59         1.05         1.50        100.0        100.0
# 7441  11.76  18.07         1.22         1.46        100.0        100.0
# 7442  25.89  10.75         1.41         0.59        100.0        100.0
#
#       score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
X=df[cont_cols]

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
imputer.fit_transform(X)
# Out:
# array([[48.22, 37.83,  1.75, ...,  0.  ,  1.39,  1.05],
#        [39.81, 60.08,  1.22, ...,  4.  ,  0.57,  0.  ],
#        [65.59, 39.99,  2.58, ...,  0.  ,  0.49,  3.15],
#        ...,
#        [12.97, 23.59,  1.05, ...,  1.  ,  0.6 ,  1.05],
#        [11.76, 18.07,  1.22, ...,  1.  ,  0.6 ,  1.05],
#        [25.89, 10.75,  1.41, ...,  1.  ,  0.6 ,  1.05]])

# %%
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     48.22  37.83         1.75         0.84         45.9         22.1
# 1     39.81  60.08         1.22         1.89         25.6         63.4
# 2     65.59  39.99         2.58         0.62         77.1         28.8
# 3     32.25  54.82         1.10         1.79         35.8         58.9
# 4     38.24  40.45         1.57         1.24         26.2         21.3
# ...     ...    ...          ...          ...          ...          ...
# 7438  34.05  33.76         1.39         1.19        100.0        100.0
# 7439  36.73  36.11         1.67         1.44        100.0        100.0
# 7440  12.97  23.59         1.05         1.50        100.0        100.0
# 7441  11.76  18.07         1.22         1.46        100.0        100.0
# 7442  25.89  10.75         1.41         0.59        100.0        100.0
#
#       score1  score2   xg1  adj_score1  season      date  league_id  \
# ...

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

numerical_preprocessor = StandardScaler()

categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")



preprocessor = ColumnTransformer([
    ('one-hot-encoder', categorical_preprocessor, cat_cols),
    ('standard-scaler', numerical_preprocessor, cont_cols)])


model = make_pipeline(preprocessor, XGBClassifier())

# %%
X=pd.concat([df[cont_cols],df[cat_cols]],axis=1)

# %%
X
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     48.22  37.83         1.75         0.84         45.9         22.1
# 1     39.81  60.08         1.22         1.89         25.6         63.4
# 2     65.59  39.99         2.58         0.62         77.1         28.8
# 3     32.25  54.82         1.10         1.79         35.8         58.9
# 4     38.24  40.45         1.57         1.24         26.2         21.3
# ...     ...    ...          ...          ...          ...          ...
# 7438  34.05  33.76         1.39         1.19        100.0        100.0
# 7439  36.73  36.11         1.67         1.44        100.0        100.0
# 7440  12.97  23.59         1.05         1.50        100.0        100.0
# 7441  11.76  18.07         1.22         1.46        100.0        100.0
# 7442  25.89  10.75         1.41         0.59        100.0        100.0
#
#       score1  score2   xg1  adj_score1  season      date  league_id  \
# ...

# %%
X_new=data_test_all[cont_cols]

# %%
X_new_fit=imputer.transform(X_new)

# %%
X_new_fit
# Out:
# array([[79.65 , 74.06 ,  1.67 , ...,  1.5  ,  1.95 ,  2.015],
#        [74.19 , 71.14 ,  1.35 , ...,  1.   ,  0.6  ,  1.05 ],
#        [60.67 , 71.45 ,  1.18 , ...,  1.   ,  0.6  ,  1.05 ],
#        ...,
#        [26.62 , 28.65 ,  1.31 , ...,  1.   ,  0.6  ,  1.05 ],
#        [33.74 , 30.32 ,  1.33 , ...,  1.   ,  0.6  ,  1.05 ],
#        [29.7  , 30.25 ,  1.38 , ...,  1.   ,  0.6  ,  1.05 ]])

# %%
data_test_all_cont = pd.DataFrame(X_new_fit, columns = cont_cols)

# %%
data_test_all_cont
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     79.65  74.06         1.67         1.19        59.60        75.55
# 1     74.19  71.14         1.35         0.98       100.00       100.00
# 2     60.67  71.45         1.18         1.49       100.00       100.00
# 3     76.88  79.06         1.52         1.44        87.55       100.00
# 4     63.53  85.58         0.95         1.92       100.00       100.00
# ...     ...    ...          ...          ...          ...          ...
# 4003  41.51  48.12         1.40         1.39       100.00       100.00
# 4004  26.77  33.53         1.17         1.18        70.95        61.55
# 4005  26.62  28.65         1.31         1.14        67.30        65.15
# 4006  33.74  30.32         1.33         0.87       100.00       100.00
# 4007  29.70  30.25         1.38         1.19       100.00       100.00
#
#       score1  score2   xg1  adj_score1
# 0        2.0     1.5  1.95       2.015
# ...

# %%
data_test_all_cont.isnull().sum()
# Out:
# SPI1           0
# SPI2           0
# proj_score1    0
# proj_score2    0
# importance1    0
# importance2    0
# score1         0
# score2         0
# xg1            0
# adj_score1     0
# dtype: int64

# %%
X=pd.concat([data_test_all_cont[cont_cols],data_test_all[cat_cols]],axis=1)

# %%
X
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     79.65  74.06         1.67         1.19        59.60        75.55
# 1     74.19  71.14         1.35         0.98       100.00       100.00
# 2     60.67  71.45         1.18         1.49       100.00       100.00
# 3     76.88  79.06         1.52         1.44        87.55       100.00
# 4     63.53  85.58         0.95         1.92       100.00       100.00
# ...     ...    ...          ...          ...          ...          ...
# 4003  41.51  48.12         1.40         1.39       100.00       100.00
# 4004  26.77  33.53         1.17         1.18        70.95        61.55
# 4005  26.62  28.65         1.31         1.14        67.30        65.15
# 4006  33.74  30.32         1.33         0.87       100.00       100.00
# 4007  29.70  30.25         1.38         1.19       100.00       100.00
#
#       score1  score2   xg1  adj_score1  season      date  league_id  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.1, random_state=42)

model.fit(X_train, y_train)
# Out:
# C:\Users\eshjaya\AppData\Roaming\Python\Python38\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:08:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('one-hot-encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
# ...

# %%
y_pred=model.predict(X_test)[:1]

# %%
y_pred_proba=model.predict_proba(X_test)[:,1]

# %%
y=y.astype(int)

y_pred=y_pred.astype(int)
y_test=y_test.astype(int)
y_train=y_train.astype(int)

# %%
y_pred_proba
# Out:
# array([9.99983430e-01, 9.99997377e-01, 9.99988914e-01, 2.23826646e-06,
#        9.99995112e-01, 9.99996066e-01, 9.99992013e-01, 9.99997854e-01,
#        9.99993563e-01, 2.23826646e-06, 9.99998689e-01, 9.99998689e-01,
#        9.99999046e-01, 9.99998212e-01, 2.11260376e-05, 1.55500347e-05,
#        9.99997973e-01, 9.99996901e-01, 9.99999166e-01, 4.21836376e-01,
#        4.14688338e-06, 9.99972939e-01, 9.99996901e-01, 9.24072927e-04,
#        9.99919653e-01, 9.99999046e-01, 9.99923229e-01, 9.99960423e-01,
#        9.99998808e-01, 9.99995947e-01, 9.99995589e-01, 9.99998689e-01,
#        9.99994040e-01, 9.99996662e-01, 9.99998808e-01, 3.72151794e-06,
#        9.99989033e-01, 9.99996662e-01, 2.55011790e-03, 9.99998212e-01,
#        9.99999166e-01, 9.99997616e-01, 9.99842048e-01, 9.99994993e-01,
#        9.99996901e-01, 9.99997497e-01, 9.99995708e-01, 1.91025010e-05,
#        9.99988437e-01, 6.17132464e-05, 9.99997735e-01, 9.11700990e-05,
# ...

# %%
from sklearn.metrics import log_loss
log_loss(y_test,y_pred_proba)
# Out:
# 0.035912751917163595

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred,y_test)
# Out:
# 0.9919463087248322

# %%
from sklearn.model_selection import cross_validate
cv_results = cross_validate(model, X_train, y_train, cv=5)
cv_results
# Out:
# C:\Users\eshjaya\AppData\Roaming\Python\Python38\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:12:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
scores = cv_results["test_score"]
print("The mean cross-validation accuracy is: "
      f"{scores.mean():.3f} +/- {scores.std():.3f}")
# Out:
# The mean cross-validation accuracy is: 0.992 +/- 0.001

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from  lightgbm import LGBMClassifier

numerical_preprocessor = StandardScaler()

categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")



preprocessor = ColumnTransformer([
    ('one-hot-encoder', categorical_preprocessor, cat_cols),
    ('standard-scaler', numerical_preprocessor, cont_cols)])


model = make_pipeline(preprocessor, LGBMClassifier())

# %%
data_test_all = pd.read_csv("LHS_WE_2_Soccer_Fever_test.csv")

data_test_all
# Out:
#       season      date  league_id                    league  \
# 0       2021  14/12/21       2411                       BPL
# 1       2021  14/12/21       2411                       BPL
# 2       2021  14/12/21       2411                       BPL
# 3       2021  14/12/21       2411                       BPL
# 4       2021  14/12/21       2411                       BPL
# ...      ...       ...        ...                       ...
# 4003    2021  29/05/22       1871  Spanish Segunda Division
# 4004    2021  29/05/22       1871  Spanish Segunda Division
# 4005    2021  29/05/22       1871  Spanish Segunda Division
# 4006    2021  29/05/22       1871  Spanish Segunda Division
# 4007    2021  29/05/22       1871  Spanish Segunda Division
#
#                         Team 1              Team2   SPI1   SPI2  proj_score1  \
# 0                      Arsenal    West Ham United  79.65  74.06         1.67
# 1     Brighton and Hove Albion      Wolverhampton  74.19  71.14         1.35
# ...

# %%
cont_cols=[ 'SPI1' , 'SPI2','proj_score1','proj_score2','importance1','importance2','score1','score2','xg1','adj_score1']

cat_cols =['season', 'date', 'league_id', 'league', 'Team 1', 'Team2']

y=df['Outcome']

# %%
X=pd.concat([data_test_all[cont_cols],data_test_all[cat_cols]],axis=1)

# %%
X
# Out:
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     79.65  74.06         1.67         1.19        100.0        100.0
# 1     74.19  71.14         1.35         0.98        100.0        100.0
# 2     60.67  71.45         1.18         1.49        100.0        100.0
# 3     76.88  79.06         1.52         1.44        100.0        100.0
# 4     63.53  85.58         0.95         1.92        100.0        100.0
# ...     ...    ...          ...          ...          ...          ...
# 4003  41.51  48.12         1.40         1.39        100.0        100.0
# 4004  26.77  33.53         1.17         1.18        100.0        100.0
# 4005  26.62  28.65         1.31         1.14        100.0        100.0
# 4006  33.74  30.32         1.33         0.87        100.0        100.0
# 4007  29.70  30.25         1.38         1.19        100.0        100.0
#
#       score1  score2  xg1  adj_score1  season      date  league_id  \
# ...

# %%
X=pd.concat([data_test_all[cont_cols],data_test_all[cat_cols]],axis=1)

# %%
y_pred_test=model.predict_proba(X)[:,1]

# %%
y_pred_test
# Out:
# array([9.9999690e-01, 9.9999154e-01, 7.3417000e-06, ..., 9.9988914e-01,
#        9.9998713e-01, 9.9991536e-01], dtype=float32)

# %%
import math

math.exp(0.035912751917163595)
# Out:
# 1.0365654042012717

# %%
predic = pd.DataFrame(y_pred_test,columns=["Outcome"] )

predic.to_csv("./submission.csv")
